# %% [markdown]
# ### 패키지 만들어 사용하기 Creating a Python Package
#
# >1. 새로운 폴더 생성 ('jupyterworkflow')
# >2. 해당 폴더에 '__init__.py', 'data.py' 파일 생성
# >> * data.py : data dawnload package

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# data.py 패키지를 호출하여 데이터를 다운로드 함
# C:\Users\pc\JupyterWorkflowEx\jupyterworkflow\data.py
from jupyterworkflow.data import get_fremont_data

# %%
data = get_fremont_data()
data.head()
# Out:
#                      West  East  Total
# Date
# 2012-10-03 12:00:00   4.0   9.0   13.0
# 2012-10-03 01:00:00   4.0   6.0   10.0
# 2012-10-03 02:00:00   1.0   1.0    2.0
# 2012-10-03 03:00:00   2.0   3.0    5.0
# 2012-10-03 04:00:00   6.0   1.0    7.0

# %%
data.resample('W').sum().plot();

# %%
data.groupby(data.index.time).mean().plot();

# %%
pivoted = data.pivot_table('Total', index = data.index.time, columns = data.index.date)
pivoted.iloc[:5, :5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 01:00:00        50.0        64.5        60.0        96.0       122.5
# 02:00:00        65.0        64.0        66.0       106.0       122.0
# 03:00:00        84.5        75.0        84.0       107.0       118.5
# 04:00:00       161.0       141.5       159.5        94.0       114.0
# 05:00:00       307.0       266.5       229.5        92.5       100.0

# %%
pivoted.plot(legend = False, alpha = 0.01);

# %%
# get_fremont_data? : get_fremont_data 의 정보를 볼 수 있다.
# get_fremont_data? : get_fremont_data 의 소스 코드를 볼 수 있다.
# get_fremont_data + shift+Tab : 함수의 옵션을 볼 수 있다
